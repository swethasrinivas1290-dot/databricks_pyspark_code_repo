# %%
# %sql
create volume if not exists volumewd36

# %%
base_path = "/Volumes/workspace/default/volumewd36"
raw_path = f"{base_path}/raw"
processed_path = f"{base_path}/processed"
archive_path = f"{base_path}/archive"

# %%
dbutils.fs.mkdirs(raw_path)
dbutils.fs.mkdirs(processed_path)
dbutils.fs.mkdirs(archive_path)

# %%
sample_data = """patient_id,patient_name,age,gender 
1,John Doe,68,M 
2,Jane Smith,54,F """
dbutils.fs.put("/Volumes/workspace/default/volumewd36/raw/sampledata.csv",sample_data,overwrite=True)

# %%
dbutils.fs.ls("/Volumes/workspace/default/volumewd36/raw/")

# %%
dbutils.fs.cp("/Volumes/workspace/default/volumewd36/raw/sampledata.csv", "/Volumes/workspace/default/volumewd36/processed/sampledata.csv")

# %%
dbutils.widgets.text("Owner name", "Arun", "Enter owner")
dbutils.widgets.dropdown("Environment", "dev", ["dev", "test", "prod"], "Select environment")

# %%
owner_name=dbutils.widgets.get("Owner name")
env=dbutils.widgets.get("Environment")
print(f"Owner name is {owner_name} and environment is {env}")

# %%
dbutils.fs.mv("/Volumes/workspace/default/volumewd36/processed/sampledata.csv", "/Volumes/workspace/default/volumewd36/archive/sampledata.csv")

# %%
file_name = dbutils.widgets.get("sampledata.csv")
source_path=f"/Volumes/workspace/default/volumewd36/processed/{file_name}"
destination_path=f"/Volumes/workspace/default/volumewd36/archive/{file_name}"
dbutils.fs.mv(source_path,destination_path)

# %%
dbutils.notebook.run("/Workspace/Repos/databricks_pyspark_code_repo/databricks_pyspark_code_repo/practice_files/4_child_nb_dataload",600)

# %%
dbutils.notebook.exit("Pipeline completed successfully")
