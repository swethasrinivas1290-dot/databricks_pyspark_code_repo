# %% [markdown]
# #Started learning Databricks
# usecase Notebook Fundamentals <br>
# ![](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)
# $${\color{pink}My-Name-swetha}$$
# _This is an italic text_
# **$${\color{blue} bold coloured text}$$**
# **bold text**<br>
# *italic*

# %%
# %sql
create VOLUME if not exists workspace.default.usage_metrics

# %%
import requests
data =requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
dbutils.fs.put("dbfs:/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",data.text)

# %%
# %run 
"/Workspace/Repos/databricks_pyspark_code_repo/databricks_pyspark_code_repo/practice_files/4_child_nb_dataload"

# %%
# %sh ls /Volumes/workspace/default/usage_metrics

# %%
# %fs head /Volumes/workspace/default/usage_metrics/mobile_os_usage.csv

# %%
df1=spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")

# %%
df1.write.mode("overwrite").saveAsTable("default.mobile_os_usage")

# %%
spark.sql("SELECT * FROM default.mobile_os_usage").show()

# %%
def upper1(a):
    return a.upper

# %%
print("converted the string to upper case:", upper1("swetha"))

# %%
pip install pandas

# %%
import pandas as pd
df = pd.read_csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
print(df)

# %%
# %sh
echo "Magic commands tasks completed"
