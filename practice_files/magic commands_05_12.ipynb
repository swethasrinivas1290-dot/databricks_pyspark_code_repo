# %%
# %fs

# %%
# %run 
"/Workspace/Repos/databricks_pyspark_code_repo/databricks_pyspark_code_repo/practice_files/Ued Notebook 2025-12-22 18_47_00"

# %%
# %sql
create volume if not exists workspace.default.usage_metrics
